# %%
import numpy as np
from scipy.integrate import odeint

# %%
def pend(y, t, b):
...     theta, omega = y
...     dydt = [omega, -b*np.sin(theta)]
...     return dydt

# %%
b=9.8/5

# %%
y0 = [np.radians(20), 0.0]

# %%
t = np.linspace(0, 20, 201)

# %%
sol = odeint(pend, y0, t, args=(b,))

# %%
import matplotlib.pyplot as plt
plt.plot(t, np.degrees(sol[:, 0]), 'b', label='Exact')
plt.plot(t, np.degrees(y0[0]*np.cos(np.sqrt(b)*t)), 'r', label='Approximation')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()
